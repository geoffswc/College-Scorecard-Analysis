# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
df = pd.read_csv('data/FieldOfStudyData1516_1617_PP.csv')

# %%
pysqldf("""
SELECT 
    * 
FROM 
    df 
WHERE 
    INSTNM LIKE '%Mitchell College%'

""")
# Out:
#       UNITID  OPEID6            INSTNM             CONTROL  MAIN  CIPCODE  \
# 0   129774.0  1393    Mitchell College  Private, nonprofit  1     301
# 1   129774.0  1393    Mitchell College  Private, nonprofit  1     901
# 2   129774.0  1393    Mitchell College  Private, nonprofit  1     1101
# 3   129774.0  1393    Mitchell College  Private, nonprofit  1     1312
# 4   129774.0  1393    Mitchell College  Private, nonprofit  1     1312
# 5   129774.0  1393    Mitchell College  Private, nonprofit  1     1401
# 6   129774.0  1393    Mitchell College  Private, nonprofit  1     1907
# 7   129774.0  1393    Mitchell College  Private, nonprofit  1     2401
# 8   129774.0  1393    Mitchell College  Private, nonprofit  1     2401
# 9   129774.0  1393    Mitchell College  Private, nonprofit  1     2613
# 10  129774.0  1393    Mitchell College  Private, nonprofit  1     3101
# 11  129774.0  1393    Mitchell College  Private, nonprofit  1     3105
# ...

# %%
#ok, so they're using the 2015-2017 data!
